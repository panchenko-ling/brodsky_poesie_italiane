# %%
import csv
from xml.etree.ElementTree import Element, SubElement, tostring
from xml.dom import minidom
from google.colab import files

# %%
filename = "Brodsky_XML_Locations.csv"
coordinates = "Brodsky_Coordinates.csv"

# %%
def csv_to_places_xml(main_csv, coord_csv):
    seen_keys = set()
    root = Element("places")

    coords_dict = {}
    with open(coord_csv, newline='', encoding='utf-8') as f_coords:
        reader_coords = csv.DictReader(f_coords, delimiter=';')
        for row in reader_coords:
            key = row.get("Location key", "").strip()
            if key:
                lat = row.get("Lat", "").strip()
                lon = row.get("Long", "").strip()
                coords_dict[key] = (lat, lon)

    with open(main_csv, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            location_key = row.get("Location key", "").strip()
            if not location_key or location_key in seen_keys:
                continue
            seen_keys.add(location_key)

            place = Element("place")
            place.set("xml:id", location_key)

            location_type = row.get("Location type", "").strip()
            if location_type:
                place.set("type", location_type)

            location = row.get("Location", "").strip()
            place_name = SubElement(place, "placeName")
            place_name.set("{http://www.w3.org/XML/1998/namespace}lang", "en")
            place_name.text = location

            location_elem = SubElement(place, "location")

            country = row.get("Country", "").strip()
            if country and country != "NA":
                country_elem = SubElement(location_elem, "country")
                country_elem.text = country

            city = row.get("City", "").strip()
            if city and city != "NA":
                city_elem = SubElement(location_elem, "city")
                city_elem.text = city

            if location_key in coords_dict:
                lat, lon = coords_dict[location_key]
                if lat and lon:
                    geo_elem = SubElement(location_elem, "geo")
                    geo_elem.text = f"{lat} {lon}"

            root.append(place)

    rough_string = tostring(root, encoding="utf-8")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="  ", encoding="utf-8").decode("utf-8")

# %%
xml_output = csv_to_places_xml(filename, coordinates)
print(xml_output)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <places>
#   <place xml:id="roman_empire" type="ancient_country">
#     <placeName xml:lang="en">Roman Empire</placeName>
#     <location>
#       <country>Italy</country>
#     </location>
#   </place>
#   <place xml:id="venetian_lagoon" type="bay">
#     <placeName xml:lang="en">Venetian Lagoon</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#     </location>
#   </place>
#   <place xml:id="pension_accademia" type="hotel">
#     <placeName xml:lang="en">Pension Accademia</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#       <geo>45.4320649 12.3270656</geo>
#     </location>
#   </place>
#   <place xml:id="venice" type="city">
#     <placeName xml:lang="en">Venice</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#     </location>
#   </place>
#   <place xml:id="adriatic_sea" type="sea">
#     <placeName xml:lang="en">Adriatic Sea</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#     </location>
#   </place>
#   <place xml:id="sphinxs_quay" type="monument">
#     <placeName xml:lang="en">Quay with Sphinxes</placeName>
#     <location>
#       <country>Russia</country>
#       <city>Saint-Petersburg</city>
#     </location>
#   </place>
#   <place xml:id="leone_san_marco" type="monument">
#     <placeName xml:lang="en">Lion of Saint Mark</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#     </location>
#   </place>
#   <place xml:id="san_marco_square" type="square">
#     <placeName xml:lang="en">Piazza San Marco</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#       <geo>45.4341668 12.3384717</geo>
#     </location>
#   </place>
#   <place xml:id="mediterranean_sea" type="sea">
#     <placeName xml:lang="en">Mediterranean Sea</placeName>
#     <location>
#       <country>Italy</country>
#     </location>
#   </place>
#   <place xml:id="florence" type="city">
#     <placeName xml:lang="en">Florence</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Florence</city>
#     </location>
#   </place>
#   <place xml:id="arno_river" type="river">
#     <placeName xml:lang="en">Arno</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Florence</city>
#     </location>
#   </place>
#   <place xml:id="signoria_square" type="square">
#     <placeName xml:lang="en">Piazza della Signoria</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Florence</city>
#       <geo>43.7696855 11.2556422</geo>
#     </location>
#   </place>
#   <place xml:id="ponte_vecchio_bridge" type="bridge">
#     <placeName xml:lang="en">Ponte Vecchio</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Florence</city>
#       <geo>43.767925 11.2531435</geo>
#     </location>
#   </place>
#   <place xml:id="san_lorenzo_basilica" type="church">
#     <placeName xml:lang="en">Basilica of San Lorenzo</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Florence</city>
#       <geo>43.7749619 11.2538762</geo>
#     </location>
#   </place>
#   <place xml:id="ravenna" type="city">
#     <placeName xml:lang="en">Ravenna</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Ravenna</city>
#     </location>
#   </place>
#   <place xml:id="san_pietro_island_venice" type="island">
#     <placeName xml:lang="en">San Pietro di Castello (island)</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#     </location>
#   </place>
#   <place xml:id="vittorio_emmanuele_monument_venice" type="monument">
#     <placeName xml:lang="en">Monument to Victor Emmanuel II</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#       <geo>45.4338948 12.3433492</geo>
#     </location>
#   </place>
#   <place xml:id="san_marco_basilica" type="church">
#     <placeName xml:lang="en">St Mark's Basilica</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#       <geo>45.4345606 12.3397124</geo>
#     </location>
#   </place>
#   <place xml:id="mattei_square" type="square">
#     <placeName xml:lang="en">Piazza Mattei</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#     </location>
#   </place>
#   <place xml:id="turtle_fountain" type="historical_landmark">
#     <placeName xml:lang="en">Fontana delle Tartarughe</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#       <geo>41.8938343 12.4775765</geo>
#     </location>
#   </place>
#   <place xml:id="rome" type="city">
#     <placeName xml:lang="en">Rome</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#     </location>
#   </place>
#   <place xml:id="terme_di_caracalla" type="historical_landmark">
#     <placeName xml:lang="en">Baths of Caracalla</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#       <geo>41.8790526 12.4926304</geo>
#     </location>
#   </place>
#   <place xml:id="colosseum" type="historical_landmark">
#     <placeName xml:lang="en">Colosseum</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#       <geo>41.8902102 12.4922309</geo>
#     </location>
#   </place>
#   <place xml:id="via_dei_funari" type="street">
#     <placeName xml:lang="en">Via dei Funari</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#       <geo>41.8937871 12.4785082</geo>
#     </location>
#   </place>
#   <place xml:id="europe" type="continent">
#     <placeName xml:lang="en">Europe</placeName>
#     <location/>
#   </place>
#   <place xml:id="ussr" type="country">
#     <placeName xml:lang="en">USSR</placeName>
#     <location>
#       <country>Russia</country>
#     </location>
#   </place>
#   <place xml:id="us" type="country">
#     <placeName xml:lang="en">US</placeName>
#     <location>
#       <country>US</country>
#     </location>
#   </place>
#   <place xml:id="tanais" type="ancient_city">
#     <placeName xml:lang="en">Tanais</placeName>
#     <location>
#       <country>Russia</country>
#       <city>Rostov-on-Don</city>
#     </location>
#   </place>
#   <place xml:id="perm" type="city">
#     <placeName xml:lang="en">Perm</placeName>
#     <location>
#       <country>Russia</country>
#       <city>Perm</city>
#     </location>
#   </place>
#   <place xml:id="italy" type="country">
#     <placeName xml:lang="en">Italy</placeName>
#     <location>
#       <country>Italy</country>
#     </location>
#   </place>
#   <place xml:id="saint_petersburg" type="city">
#     <placeName xml:lang="en">Saint Petersburg</placeName>
#     <location>
#       <country>Russia</country>
#       <city>Saint-Petersburg</city>
#     </location>
#   </place>
#   <place xml:id="tiber" type="river">
#     <placeName xml:lang="en">Tiber</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#     </location>
#   </place>
#   <place xml:id="via_giulia" type="street">
#     <placeName xml:lang="en">Via Giulia</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#       <geo>41.8962558 12.4681342</geo>
#     </location>
#   </place>
#   <place xml:id="bar_gianicolo" type="local_place">
#     <placeName xml:lang="en">Bar Gianicolo</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#       <geo>41.8882528 12.4612167</geo>
#     </location>
#   </place>
#   <place xml:id="lombardia" type="region">
#     <placeName xml:lang="en">Lombardia</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Milan</city>
#     </location>
#   </place>
#   <place xml:id="africa" type="continent">
#     <placeName xml:lang="en">Africa</placeName>
#     <location/>
#   </place>
#   <place xml:id="alps" type="mountains">
#     <placeName xml:lang="en">Alps</placeName>
#     <location>
#       <country>Italy</country>
#     </location>
#   </place>
#   <place xml:id="apennines" type="mountains">
#     <placeName xml:lang="en">Apennines</placeName>
#     <location>
#       <country>Italy</country>
#     </location>
#   </place>
#   <place xml:id="la_scala" type="historical_landmark">
#     <placeName xml:lang="en">La Scala</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Milan</city>
#     </location>
#   </place>
#   <place xml:id="milan" type="city">
#     <placeName xml:lang="en">Milan</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Milan</city>
#     </location>
#   </place>
#   <place xml:id="bethlehem" type="city">
#     <placeName xml:lang="en">Bethlehem</placeName>
#     <location>
#       <country>Palestine</country>
#       <city>Bethlehem</city>
#     </location>
#   </place>
#   <place xml:id="palestine" type="country">
#     <placeName xml:lang="en">Palestine</placeName>
#     <location>
#       <country>Palestine</country>
#     </location>
#   </place>
#   <place xml:id="ischia" type="island">
#     <placeName xml:lang="en">Ischia</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Naples</city>
#     </location>
#   </place>
#   <place xml:id="epomeo" type="mountains">
#     <placeName xml:lang="en">Mount Epomeo</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Naples</city>
#     </location>
#   </place>
#   <place xml:id="egypt" type="country">
#     <placeName xml:lang="en">Egypt</placeName>
#     <location>
#       <country>Egypt</country>
#     </location>
#   </place>
#   <place xml:id="hotel_meleager_atalanta" type="local_place">
#     <placeName xml:lang="en">Hotel &quot;Meleager and Atalanta&quot;</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#     </location>
#   </place>
#   <place xml:id="auschwitz" type="concentration_camp">
#     <placeName xml:lang="en">Auschwitz</placeName>
#     <location>
#       <country>Poland</country>
#       <city>Oświęcim</city>
#     </location>
#   </place>
#   <place xml:id="procida" type="island">
#     <placeName xml:lang="en">Procida</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Naples</city>
#     </location>
#   </place>
#   <place xml:id="palazzo_caetani" type="building">
#     <placeName xml:lang="en">Palazzo Caetani</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#       <geo>41.8940027 12.4783013</geo>
#     </location>
#   </place>
#   <place xml:id="camiceria_via_funari" type="local_place">
#     <placeName xml:lang="en">Camiceria (Via dei Funari)</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#       <geo>41.8937368 12.4785137</geo>
#     </location>
#   </place>
#   <place xml:id="tunisia" type="country">
#     <placeName xml:lang="en">Tunisia</placeName>
#     <location>
#       <country>Tunisia</country>
#     </location>
#   </place>
#   <place xml:id="libya" type="country">
#     <placeName xml:lang="en">Libya</placeName>
#     <location>
#       <country>Libya</country>
#     </location>
#   </place>
#   <place xml:id="hotel_quirinale" type="hotel">
#     <placeName xml:lang="en">Hotel Quirinale</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Rome</city>
#       <geo>41.9016232 12.4948552</geo>
#     </location>
#   </place>
#   <place xml:id="palazzo_minelli" type="building">
#     <placeName xml:lang="en">Palazzo Minelli</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#       <geo>45.43449 12.3342294</geo>
#     </location>
#   </place>
#   <place xml:id="casa_marcello" type="building">
#     <placeName xml:lang="en">Girolamo Marcello's Palace (Rio de la Verona)</placeName>
#     <location>
#       <country>Italy</country>
#       <city>Venice</city>
#       <geo>45.4340984 12.3331228</geo>
#     </location>
#   </place>
# </places>

# %%
def csv_to_persons_xml(csv_file):
    seen_keys = set()
    root = Element("persons")

    with open(csv_file, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            name_key = row.get("Name key", "").strip()
            if not name_key or name_key in seen_keys:
                continue
            seen_keys.add(name_key)

            person_elem = Element("person")
            person_elem.set("xml:id", name_key)

            pers_name = SubElement(person_elem, "persName")
            pers_name.set("{http://www.w3.org/XML/1998/namespace}lang", "en")
            pers_name.text = row.get("Person / Entity", "").strip()

            type_val = row.get("Type", "").strip()
            if type_val and type_val != "NA":
                for t in type_val.split(","):
                    t = t.strip()
                    if t:
                        type_elem = SubElement(person_elem, "type")
                        type_elem.text = t

            role_val = row.get("Role", "").strip()
            if role_val and role_val != "NA":
                for r in role_val.split(","):
                    r = r.strip()
                    if r:
                        role_elem = SubElement(person_elem, "role")
                        role_elem.text = r

            birth_val = row.get("Birth_year", "").strip()
            if birth_val and birth_val != "NA":
                birth_elem = SubElement(person_elem, "birth")
                birth_elem.set("when", birth_val)
                birth_elem.text = birth_val

            death_val = row.get("Death_year", "").strip()
            if death_val and death_val != "NA":
                death_elem = SubElement(person_elem, "death")
                death_elem.set("when", death_val)
                death_elem.text = death_val

            year_val = row.get("Year", "").strip()
            if year_val and year_val != "NA":
                date_elem = SubElement(person_elem, "date")
                date_elem.set("when", year_val)
                date_elem.text = year_val

            country_val = row.get("Country", "").strip()
            if country_val and country_val != "NA":
                for c in country_val.split(","):
                    c = c.strip()
                    if c:
                        country_elem = SubElement(person_elem, "country")
                        country_elem.text = c

            root.append(person_elem)

    rough_string = tostring(root, encoding="utf-8")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="  ", encoding="utf-8").decode("utf-8")

# %%
personsfile = "Brodsky_XML_Persons.csv"
persons_output = csv_to_persons_xml(personsfile)
print(persons_output)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <persons>
#   <person xml:id="god">
#     <persName xml:lang="en">God</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="chort">
#     <persName xml:lang="en">Chort</persName>
#     <type>literature_character</type>
#     <date when="1831">1831</date>
#     <country>Russia</country>
#   </person>
#   <person xml:id="solokha">
#     <persName xml:lang="en">Solokha</persName>
#     <type>literature_character</type>
#     <date when="1831">1831</date>
#     <country>Russia</country>
#   </person>
#   <person xml:id="st_sofia">
#     <persName xml:lang="en">Saint Sofia</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="st_faith">
#     <persName xml:lang="en">Saint Faith</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="st_hope">
#     <persName xml:lang="en">Saint Hope</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="st_charity">
#     <persName xml:lang="en">Saint Charity</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="akhmatova_anna">
#     <persName xml:lang="en">Anna Akhmatova</persName>
#     <type>art</type>
#     <type>acquaintance</type>
#     <role>poet</role>
#     <role>friend</role>
#     <birth when="1889">1889</birth>
#     <death when="1966">1966</death>
#     <country>Russia</country>
#   </person>
#   <person xml:id="cellini_benvenuto">
#     <persName xml:lang="en">Benvenuto Cellini</persName>
#     <type>art</type>
#     <role>sculptor</role>
#     <birth when="1500">1500</birth>
#     <death when="5171">5171</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="brunelleschi_filippo">
#     <persName xml:lang="en">Filippo Brunelleschi</persName>
#     <type>art</type>
#     <role>architect</role>
#     <birth when="1377">1377</birth>
#     <death when="1446">1446</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="evangelist">
#     <persName xml:lang="en">Evangelist (unidentified)</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="aphrodite">
#     <persName xml:lang="en">Aphrodite</persName>
#     <type>greek_mythology</type>
#     <country>Greece</country>
#   </person>
#   <person xml:id="michela_prodan">
#     <persName xml:lang="en">Michela Prodan</persName>
#     <type>acquaintance</type>
#     <role>romance</role>
#     <country>Italy</country>
#   </person>
#   <person xml:id="muses">
#     <persName xml:lang="en">Muses</persName>
#     <type>greek_mythology</type>
#     <country>Greece</country>
#   </person>
#   <person xml:id="graces">
#     <persName xml:lang="en">Graces</persName>
#     <type>roman_mythology</type>
#     <country>Italy</country>
#   </person>
#   <person xml:id="ovid">
#     <persName xml:lang="en">Ovid</persName>
#     <type>art</type>
#     <role>poet</role>
#     <birth when="43BC">43BC</birth>
#     <death when="17">17</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="virgil">
#     <persName xml:lang="en">Virgil</persName>
#     <type>art</type>
#     <role>poet</role>
#     <birth when="70BC">70BC</birth>
#     <death when="19BC">19BC</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="horace">
#     <persName xml:lang="en">Horace</persName>
#     <type>art</type>
#     <role>poet</role>
#     <birth when="65BC">65BC</birth>
#     <death when="8BC">8BC</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="euterpe">
#     <persName xml:lang="en">Euterpe</persName>
#     <type>greek_mythology</type>
#     <country>Greece</country>
#   </person>
#   <person xml:id="michelangelo">
#     <persName xml:lang="en">Michelangelo Buonarotti</persName>
#     <type>art</type>
#     <role>sculptor</role>
#     <birth when="1475">1475</birth>
#     <death when="1564">1564</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="borromini_francesco">
#     <persName xml:lang="en">Francesco Borromini</persName>
#     <type>art</type>
#     <role>architect</role>
#     <birth when="1599">1599</birth>
#     <death when="1667">1667</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="parcae">
#     <persName xml:lang="en">Parcae</persName>
#     <type>roman_mythology</type>
#     <country>Italy</country>
#   </person>
#   <person xml:id="tasso_torquato">
#     <persName xml:lang="en">Torquato Tasso</persName>
#     <type>art</type>
#     <role>poet</role>
#     <birth when="1544">1544</birth>
#     <death when="1595">1595</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="church_fathers">
#     <persName xml:lang="en">Church Fathers</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="craveri_benedetta">
#     <persName xml:lang="en">Benedetta Craveri</persName>
#     <type>acquaintance</type>
#     <role>literary_critic</role>
#     <role>friend</role>
#     <birth when="1942">1942</birth>
#     <country>Italy</country>
#   </person>
#   <person xml:id="argus">
#     <persName xml:lang="en">Argus</persName>
#     <type>greek_mythology</type>
#     <country>Greece</country>
#   </person>
#   <person xml:id="caruso_enrico">
#     <persName xml:lang="en">Enrico Caruso</persName>
#     <type>art</type>
#     <role>singer</role>
#     <birth when="1873">1873</birth>
#     <death when="1921">1921</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="lesbia">
#     <persName xml:lang="en">Lesbia</persName>
#     <type>historical_character</type>
#     <country>Italy</country>
#   </person>
#   <person xml:id="julia_the_elder">
#     <persName xml:lang="en">Julia the Elder</persName>
#     <type>historical_character</type>
#     <birth when="39BC">39BC</birth>
#     <death when="14">14</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="cynthia_propertius">
#     <persName xml:lang="en">Cynthia (Propertius)</persName>
#     <type>historical_character</type>
#     <country>Italy</country>
#   </person>
#   <person xml:id="livia_drusilla">
#     <persName xml:lang="en">Livia Drusilla</persName>
#     <type>historical_character</type>
#     <birth when="59BC">59BC</birth>
#     <death when="29">29</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="malevich_kazimir">
#     <persName xml:lang="en">Kazimir Malevich</persName>
#     <type>art</type>
#     <role>artist</role>
#     <birth when="1879">1879</birth>
#     <death when="1935">1935</death>
#     <country>Russia</country>
#   </person>
#   <person xml:id="romulus">
#     <persName xml:lang="en">Remus</persName>
#     <type>roman_mythology</type>
#     <country>Italy</country>
#   </person>
#   <person xml:id="remus">
#     <persName xml:lang="en">Romulus</persName>
#     <type>roman_mythology</type>
#     <country>Italy</country>
#   </person>
#   <person xml:id="sontag_susan">
#     <persName xml:lang="en">Susan Sontag</persName>
#     <type>art</type>
#     <type>acquaintance</type>
#     <role>writer</role>
#     <role>romance</role>
#     <birth when="1933">1933</birth>
#     <death when="2004">2004</death>
#     <country>US</country>
#   </person>
#   <person xml:id="iago_otello">
#     <persName xml:lang="en">Iago</persName>
#     <type>literature_character</type>
#     <date when="1603">1603</date>
#     <country>UK</country>
#   </person>
#   <person xml:id="duse_eleonora">
#     <persName xml:lang="en">Eleonora Duse</persName>
#     <type>art</type>
#     <role>actress</role>
#     <birth when="1858">1858</birth>
#     <death when="1924">1924</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="nereids">
#     <persName xml:lang="en">Nereids</persName>
#     <type>greek_mythology</type>
#     <type>roman_mythology</type>
#     <country>Italy</country>
#     <country>Greece</country>
#   </person>
#   <person xml:id="shmakov_gennady">
#     <persName xml:lang="en">Gennady Shmakov</persName>
#     <type>art</type>
#     <type>acquaintance</type>
#     <role>poet</role>
#     <birth when="1940">1940</birth>
#     <death when="1988">1988</death>
#     <country>Russia</country>
#   </person>
#   <person xml:id="susanna">
#     <persName xml:lang="en">Susanna</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="the_elders">
#     <persName xml:lang="en">The elders</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="st_george">
#     <persName xml:lang="en">Saint George</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="calasso_roberto">
#     <persName xml:lang="en">Roberto Calasso</persName>
#     <type>art</type>
#     <type>acquaintance</type>
#     <role>writer</role>
#     <role>friend</role>
#     <birth when="1941">1941</birth>
#     <death when="2021">2021</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="jaeggy_fleur">
#     <persName xml:lang="en">Fleur Jaeggy</persName>
#     <type>art</type>
#     <type>acquaintance</type>
#     <role>writer</role>
#     <role>friend</role>
#     <birth when="1940">1940</birth>
#     <country>Italy</country>
#     <country>Switzerland</country>
#   </person>
#   <person xml:id="tiberius">
#     <persName xml:lang="en">Tiberius</persName>
#     <type>historical_character</type>
#     <role>roman_emperor</role>
#     <birth when="42BC">42BC</birth>
#     <death when="37">37</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="suetonius">
#     <persName xml:lang="en">Suetonius</persName>
#     <type>art</type>
#     <role>writer</role>
#     <birth when="69">69</birth>
#     <death when="122">122</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="tacitus">
#     <persName xml:lang="en">Tacitus</persName>
#     <type>art</type>
#     <role>writer</role>
#     <birth when="55">55</birth>
#     <death when="120">120</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="teodora_l">
#     <persName xml:lang="en">Teodora L.</persName>
#     <type>acquaintance</type>
#     <role>romance</role>
#     <country>US</country>
#   </person>
#   <person xml:id="suzanne_martin">
#     <persName xml:lang="en">Suzanne Martin</persName>
#     <type>acquaintance</type>
#     <birth when="1924">1924</birth>
#     <death when="2004">2004</death>
#     <country>France</country>
#   </person>
#   <person xml:id="vertumnus">
#     <persName xml:lang="en">Vertumnus</persName>
#     <type>roman_mythology</type>
#     <country>Italy</country>
#   </person>
#   <person xml:id="buttafava_giovanni">
#     <persName xml:lang="en">Giovanni Buttafava</persName>
#     <type>art</type>
#     <type>acquaintance</type>
#     <role>translator</role>
#     <role>friend</role>
#     <birth when="1939">1939</birth>
#     <death when="1990">1990</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="maupassant">
#     <persName xml:lang="en">Guy de Maupassant</persName>
#     <type>art</type>
#     <role>writer</role>
#     <birth when="1850">1850</birth>
#     <death when="1893">1893</death>
#     <country>France</country>
#   </person>
#   <person xml:id="nietzsche">
#     <persName xml:lang="en">Friedrich Nietzsche</persName>
#     <type>art</type>
#     <role>philosopher</role>
#     <birth when="1844">1844</birth>
#     <death when="1900">1900</death>
#     <country>Germany</country>
#   </person>
#   <person xml:id="yavashev_christo">
#     <persName xml:lang="en">Сhristo Yavashev</persName>
#     <type>art</type>
#     <role>sculptor</role>
#     <role>artist</role>
#     <birth when="1935">1935</birth>
#     <death when="2020">2020</death>
#     <country>US</country>
#   </person>
#   <person xml:id="caravaggio">
#     <persName xml:lang="en">Caravaggio</persName>
#     <type>art</type>
#     <role>artist</role>
#     <birth when="1571">1571</birth>
#     <death when="1610">1610</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="bernini">
#     <persName xml:lang="en">Gian Lorenzo Bernini</persName>
#     <type>art</type>
#     <role>sculptor</role>
#     <role>architect</role>
#     <role>artist</role>
#     <birth when="1598">1598</birth>
#     <death when="1680">1680</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="jesus">
#     <persName xml:lang="en">Jesus</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="mother_mary">
#     <persName xml:lang="en">Mary, mother of Jesus</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="st_joseph">
#     <persName xml:lang="en">Saint Joseph</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="biblical_magi">
#     <persName xml:lang="en">Biblical Magi</persName>
#     <type>christianity</type>
#   </person>
#   <person xml:id="malcovatti_fausto">
#     <persName xml:lang="en">Fausto Malcovatti</persName>
#     <type>art</type>
#     <role>translator</role>
#     <birth when="1940">1940</birth>
#     <country>Italy</country>
#   </person>
#   <person xml:id="auden_w_h">
#     <persName xml:lang="en">Wystan Hugh Auden</persName>
#     <type>art</type>
#     <type>acquaintance</type>
#     <role>poet</role>
#     <role>friend</role>
#     <birth when="1907">1907</birth>
#     <death when="1973">1973</death>
#     <country>UK</country>
#     <country>US</country>
#   </person>
#   <person xml:id="brodsky_anna">
#     <persName xml:lang="en">Anna Brodsky</persName>
#     <type>acquaintance</type>
#     <role>child</role>
#     <birth when="1993">1993</birth>
#     <country>Italy</country>
#     <country>US</country>
#   </person>
#   <person xml:id="sozzani_maria">
#     <persName xml:lang="en">Maria Sozzani</persName>
#     <type>acquaintance</type>
#     <role>spouse</role>
#     <birth when="1970">1970</birth>
#     <country>Italy</country>
#     <country>US</country>
#   </person>
#   <person xml:id="aeneas">
#     <persName xml:lang="en">Aeneas</persName>
#     <type>roman_mythology</type>
#     <type>greek_mythology</type>
#     <country>Italy</country>
#     <country>Greece</country>
#   </person>
#   <person xml:id="conte_marcello_girolamo">
#     <persName xml:lang="en">Girolamo Marcello</persName>
#     <type>acquaintance</type>
#     <role>friend</role>
#     <birth when="1932">1932</birth>
#     <death when="2017">2017</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="septimius_severus">
#     <persName xml:lang="en">Septimius Severus</persName>
#     <type>historical_character</type>
#     <role>roman_emperor</role>
#     <birth when="145">145</birth>
#     <death when="211">211</death>
#     <country>Italy</country>
#   </person>
#   <person xml:id="dolabella_cornelio">
#     <persName xml:lang="en">Publio Cornelio Dolabella</persName>
#     <type>historical_character</type>
#     <birth when="85BC">85BC</birth>
#     <death when="43BC">43BC</death>
#     <country>Italy</country>
#   </person>
# </persons>
